# %%
print("Starting new Course Like Data Engineering")
# Out:
# Starting new Course Like Data Engineering

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("NS Loni Age:", 22, "Years")
print("NS Loni Height:", 5.8, "Feet", sep=' -> ')
# Out:
# NS Loni Age: 22 Years
# NS Loni Height: -> 5.8 -> Feet

# %%
# Wrong 2 line print statement

# print("Course Like Data Engineering is now running
#       sdfsdsd")

# Correct way of 2 line print statement

print("""
      Nagaraj Loni
      B.E in Computer Science
      Skills: Python, SQL, Spark, Airflow
      
      """)
# Out:
#       Nagaraj Loni
#       B.E in Computer Science
#       Skills: Python, SQL, Spark, Airflow

# %%
# Skiping line in print statement

print('NS loni'        ' is a Data Engineer')
# Out:
# NS loni is a Data Engineer
