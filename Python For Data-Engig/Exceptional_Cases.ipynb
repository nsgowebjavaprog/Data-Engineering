# %%
x = '10'

if(x > 10):
    print('x is greater than 10')
else:
    print('x is less than or equal to 10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 x = '10'
# ----> 3 if(x > 10):
#       4     print('x is greater than 10')
#       5 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
x = '10'

try:
    if(x > 10):
        print('x is greater than 10')
    else:
        print('x is less than or equal to 10')
except:
    print('x is not a number')
# Out:
# x is not a number

# %%
x = '10'

try:
    if(x > 10):
        print('x is greater than 10')
    else:
        print('x is less than or equal to 10')
except Exception as e:
    print(e)
# Out:
# '>' not supported between instances of 'str' and 'int'

# %%
name = "NS"

print(f"Name is: {name}")
# Out:
# Name is: NS

# %%
x = '10'

try:
    if(x > 10):
        print('x is greater than 10')
    else:
        print('x is less than or equal to 10')
except Exception as e:
    print(f"The error is---->{e}")
# Out:
# The error is---->'>' not supported between instances of 'str' and 'int'

# %%
x = '10'

try:
    if(x > 10):
        print('x is greater than 10')
    else:
        print('x is less than or equal to 10')
except Exception as e:
    print(e)       
    
finally:
    print('Finally will always runnnnnnnnnnnn')
# Out:
# '>' not supported between instances of 'str' and 'int'
# Finally will always runnnnnnnnnnnn

# %%
def ns_function(x):
    
    try:
        if(x % 2 == 0):
            return 'Even'
        # else:
        #     return 'Odd'
    
    except Exception as e:
        print(e)  
    
    print('This will always runnnnnnnnnnnn')    
        
ns_function(11)
# Out:
# This will always runnnnnnnnnnnn

# %%
def ns_function(x):
    
    try:
        if(x % 2 == 0):
            return 'Even'
        else:
            return 'Odd'
    
    except Exception as e:
        print(e)  
    
    print('This will always runnnnnnnnnnnn')    
        
ns_function(11)
# Out:
# 'Odd'

# %%
x = 100

def my_func():
    x = 5
    print(x)

my_func()
# Out:
# 5

# %%
x = 100

def my_func():
    x = 5
    global x
    print(x)

my_func()
# Out:
#   Cell In[20], line 5
#     global x
#     ^
# SyntaxError: name 'x' is assigned to before global declaration

# %%
x = 100

def my_func():
    x = 5 # local more priority than global
    print(x)

my_func()

# %%
x = 100

if x<100:
    print('x is less than 100')

# %%
x = 11

if x<100:
    raise Exception('x is less than 100')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 x = 11
#       3 if x<100:
# ----> 4     raise Exception('x is less than 100')
#
# Exception: x is less than 100

# %%
x = 11

if x<100:
    raise TypeError('x is less than 100')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 x = 11
#       3 if x<100:
# ----> 4     raise TypeError('x is less than 100')
#
# TypeError: x is less than 100

# %% [markdown]
# ## enumerate function

# %%
my_list = [100,200,300,400,500]

for i in enumerate(my_list): # it will give us the index and value of the list in the form of tuple
    print(i)
# Out:
# (0, 100)
# (1, 200)
# (2, 300)
# (3, 400)
# (4, 500)
